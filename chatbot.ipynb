# %% [markdown]
# #app

# %%
import nltk
nltk.download('popular')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np

from keras.models import load_model
model = load_model('model.h5')
import json
import random
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular

# %%
intents = json.loads(open('/content/data.json').read())
words = pickle.load(open('/content/texts.pkl','rb'))
classes = pickle.load(open('/content/labels.pkl','rb'))

# %%
def clean_up_sentence(sentence):

    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)

    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# %%
# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

# %%
def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

# %%
def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res

# %%
from flask import Flask, render_template, request

app = Flask(__name__)
app.static_folder = 'static'

@app.route("/")
def home():
    return render_template("/content/index.html")

@app.route("/get")
def get_bot_response():
    userText = request.args.get('msg')
    return chatbot_response(userText)


if __name__ == "__main__":
    app.debug = True

# %% [markdown]
# #Training

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('/content/data.json').read()
intents = json.loads(data_file)

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('texts.pkl','wb'))
pickle.dump(classes,open('labels.pkl','wb'))
# Out:
# 41 documents
# 13 classes ['carapenggunaan', 'fitur', 'malam', 'options', 'pagi', 'pembuataplikasi', 'sapa', 'siang', 'sore', 'tanamanherbal', 'tanpajawaban', 'tanyaaplikasi', 'terimakasih']
# 64 unique lemmatized words ['ada', 'aja', 'anda', 'apa', 'aplikasi', 'bagaimana', 'belum', 'berapa', 'bisa', 'bisakah', 'buatan', 'cara', 'dibikin', 'dibuat', 'dong', 'fitur', 'fiturnya', 'frepocery', 'gimana', 'halo', 'haloo', 'hello', 'herbal', 'hey', 'hi', 'ini', 'itu', 'jamu', 'jelaskan', 'kamu', 'kasih', 'kepada', 'makasih', 'malam', 'matur', 'mau', 'mengenai', 'menggunakan', 'nih', 'nuwun', 'obat', 'oleh', 'pada', 'pagi', 'pembuat', 'penggunaan', 'penggunaannya', 'saja', 'saya', 'selamat', 'semalat', 'siang', 'siapa', 'sih', 'sore', 'tanaman', 'tanya', 'tau', 'tentang', 'terdapat', 'terima', 'terimakasih', 'untuk', 'yang']

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('model.h5', hist)

print("model created")
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/200
# 9/9 [==============================] - 1s 4ms/step - loss: 2.5548 - accuracy: 0.0488
# Epoch 2/200
# 9/9 [==============================] - 0s 3ms/step - loss: 2.4755 - accuracy: 0.1463
# Epoch 3/200
# 9/9 [==============================] - 0s 3ms/step - loss: 2.5615 - accuracy: 0.1463
# Epoch 4/200
# 9/9 [==============================] - 0s 3ms/step - loss: 2.4809 - accuracy: 0.0976
# Epoch 5/200
# 9/9 [==============================] - 0s 3ms/step - loss: 2.3663 - accuracy: 0.1951
# Epoch 6/200
# 9/9 [==============================] - 0s 2ms/step - loss: 2.3214 - accuracy: 0.1951
# Epoch 7/200
# 9/9 [==============================] - 0s 2ms/step - loss: 2.2534 - accuracy: 0.2683
# Epoch 8/200
# 9/9 [==============================] - 0s 2ms/step - loss: 2.2703 - accuracy: 0.2195
# Epoch 9/200
# 9/9 [==============================] - 0s 3ms/step - loss: 2.1323 - accuracy: 0.3902
# Epoch 10/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.9476 - accuracy: 0.4634
# Epoch 11/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.9727 - accuracy: 0.4146
# Epoch 12/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.7462 - accuracy: 0.5854
# Epoch 13/200
# 9/9 [==============================] - 0s 3ms/step - loss: 1.5662 - accuracy: 0.5854
# Epoch 14/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.5624 - accuracy: 0.5610
# Epoch 15/200
# 9/9 [==============================] - 0s 3ms/step - loss: 1.5457 - accuracy: 0.6098
# Epoch 16/200
# 9/9 [==============================] - 0s 3ms/step - loss: 1.5234 - accuracy: 0.5610
# Epoch 17/200
# 9/9 [==============================] - 0s 3ms/step - loss: 1.4057 - accuracy: 0.5854
# Epoch 18/200
# 9/9 [==============================] - 0s 3ms/step - loss: 1.3282 - accuracy: 0.6829
# Epoch 19/200
# 9/9 [==============================] - 0s 3ms/step - loss: 1.4035 - accuracy: 0.6341
# Epoch 20/200
# 9/9 [==============================] - 0s 3ms/step - loss: 1.1514 - accuracy: 0.7073
# Epoch 21/200
# 9/9 [==============================] - 0s 3ms/step - loss: 1.0286 - accuracy: 0.6585
# Epoch 22/200
# 9/9 [==============================] - 0s 2ms/step - loss: 1.2458 - accuracy: 0.6585
# Epoch 23/200
# 9/9 [==============================] - 0s 3ms/step - loss: 1.0720 - accuracy: 0.7317
# Epoch 24/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.9868 - accuracy: 0.6585
# Epoch 25/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.9571 - accuracy: 0.7561
# Epoch 26/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.7309 - accuracy: 0.8293
# Epoch 27/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.7327 - accuracy: 0.8537
# Epoch 28/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7616 - accuracy: 0.7561
# Epoch 29/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6125 - accuracy: 0.8780
# Epoch 30/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6476 - accuracy: 0.8293
# Epoch 31/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6899 - accuracy: 0.7317
# Epoch 32/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6381 - accuracy: 0.8049
# Epoch 33/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5054 - accuracy: 0.8780
# Epoch 34/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5076 - accuracy: 0.8537
# Epoch 35/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4432 - accuracy: 0.9512
# Epoch 36/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6789 - accuracy: 0.8293
# Epoch 37/200
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5983 - accuracy: 0.8049
# Epoch 38/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4478 - accuracy: 0.9268
# Epoch 39/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5842 - accuracy: 0.8537
# Epoch 40/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4359 - accuracy: 0.9024
# Epoch 41/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5192 - accuracy: 0.9024
# Epoch 42/200
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5083 - accuracy: 0.7805
# Epoch 43/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4940 - accuracy: 0.8780
# Epoch 44/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4033 - accuracy: 0.9268
# Epoch 45/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3778 - accuracy: 0.8780
# Epoch 46/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4212 - accuracy: 0.8537
# Epoch 47/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2669 - accuracy: 0.9268
# Epoch 48/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3981 - accuracy: 0.8780
# Epoch 49/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3270 - accuracy: 0.9024
# Epoch 50/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4989 - accuracy: 0.9024
# Epoch 51/200
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3308 - accuracy: 0.9024
# Epoch 52/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3463 - accuracy: 0.8780
# Epoch 53/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2388 - accuracy: 0.9512
# Epoch 54/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3903 - accuracy: 0.8537
# Epoch 55/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3016 - accuracy: 0.9268
# Epoch 56/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2888 - accuracy: 0.9268
# Epoch 57/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3022 - accuracy: 0.9268
# Epoch 58/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3082 - accuracy: 0.9024
# Epoch 59/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2194 - accuracy: 0.9512
# Epoch 60/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2335 - accuracy: 0.9268
# Epoch 61/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2207 - accuracy: 0.9512
# Epoch 62/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2463 - accuracy: 0.9024
# Epoch 63/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2011 - accuracy: 0.9268
# Epoch 64/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3058 - accuracy: 0.8537
# Epoch 65/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3942 - accuracy: 0.8780
# Epoch 66/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2931 - accuracy: 0.9268
# Epoch 67/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2289 - accuracy: 0.9512
# Epoch 68/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2260 - accuracy: 0.9512
# Epoch 69/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2905 - accuracy: 0.9268
# Epoch 70/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1831 - accuracy: 0.9512
# Epoch 71/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1630 - accuracy: 0.9756
# Epoch 72/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2822 - accuracy: 0.8537
# Epoch 73/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2484 - accuracy: 0.9268
# Epoch 74/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3751 - accuracy: 0.9268
# Epoch 75/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2062 - accuracy: 0.9268
# Epoch 76/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2063 - accuracy: 0.9512
# Epoch 77/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1429 - accuracy: 0.9512
# Epoch 78/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2990 - accuracy: 0.9512
# Epoch 79/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2284 - accuracy: 0.9512
# Epoch 80/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1475 - accuracy: 0.9756
# Epoch 81/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2491 - accuracy: 0.9024
# Epoch 82/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1951 - accuracy: 0.9024
# Epoch 83/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2125 - accuracy: 0.9268
# Epoch 84/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1911 - accuracy: 0.9512
# Epoch 85/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2201 - accuracy: 0.9512
# Epoch 86/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2701 - accuracy: 0.9024
# Epoch 87/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2750 - accuracy: 0.9024
# Epoch 88/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2646 - accuracy: 0.9512
# Epoch 89/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2156 - accuracy: 0.9512
# Epoch 90/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.5942 - accuracy: 0.8537
# Epoch 91/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2986 - accuracy: 0.8780
# Epoch 92/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2105 - accuracy: 0.9268
# Epoch 93/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2412 - accuracy: 0.9268
# Epoch 94/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1824 - accuracy: 0.9512
# Epoch 95/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2821 - accuracy: 0.9024
# Epoch 96/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1785 - accuracy: 0.9756
# Epoch 97/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1850 - accuracy: 0.9756
# Epoch 98/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1815 - accuracy: 0.9756
# Epoch 99/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2902 - accuracy: 0.9268
# Epoch 100/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1940 - accuracy: 0.9756
# Epoch 101/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1528 - accuracy: 0.9756
# Epoch 102/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1667 - accuracy: 0.9512
# Epoch 103/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1282 - accuracy: 1.0000
# Epoch 104/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1714 - accuracy: 0.9268
# Epoch 105/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1585 - accuracy: 0.9512
# Epoch 106/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1311 - accuracy: 1.0000
# Epoch 107/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1364 - accuracy: 0.9268
# Epoch 108/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0701 - accuracy: 0.9756
# Epoch 109/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1311 - accuracy: 0.9512
# Epoch 110/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0776 - accuracy: 0.9756
# Epoch 111/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2440 - accuracy: 0.9268
# Epoch 112/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1416 - accuracy: 0.9756
# Epoch 113/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0925 - accuracy: 0.9756
# Epoch 114/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1769 - accuracy: 0.9512
# Epoch 115/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1364 - accuracy: 0.9512
# Epoch 116/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2818 - accuracy: 0.9512
# Epoch 117/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1267 - accuracy: 0.9512
# Epoch 118/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2433 - accuracy: 0.8780
# Epoch 119/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1278 - accuracy: 0.9512
# Epoch 120/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1963 - accuracy: 0.9512
# Epoch 121/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0925 - accuracy: 0.9756
# Epoch 122/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2626 - accuracy: 0.8780
# Epoch 123/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1809 - accuracy: 0.9512
# Epoch 124/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1246 - accuracy: 0.9268
# Epoch 125/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1540 - accuracy: 0.9268
# Epoch 126/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1095 - accuracy: 0.9756
# Epoch 127/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1355 - accuracy: 0.9512
# Epoch 128/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1379 - accuracy: 0.9268
# Epoch 129/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1013 - accuracy: 0.9756
# Epoch 130/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1814 - accuracy: 0.9268
# Epoch 131/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2010 - accuracy: 0.9024
# Epoch 132/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1346 - accuracy: 0.9512
# Epoch 133/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1674 - accuracy: 0.9268
# Epoch 134/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1357 - accuracy: 0.9512
# Epoch 135/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1113 - accuracy: 0.9512
# Epoch 136/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0978 - accuracy: 0.9512
# Epoch 137/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1274 - accuracy: 0.9512
# Epoch 138/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1098 - accuracy: 0.9512
# Epoch 139/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1307 - accuracy: 0.9512
# Epoch 140/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0972 - accuracy: 0.9756
# Epoch 141/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1898 - accuracy: 0.9268
# Epoch 142/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1810 - accuracy: 0.9756
# Epoch 143/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1277 - accuracy: 0.9512
# Epoch 144/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0639 - accuracy: 1.0000
# Epoch 145/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1057 - accuracy: 0.9268
# Epoch 146/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1965 - accuracy: 0.9512
# Epoch 147/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1541 - accuracy: 0.9512
# Epoch 148/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1366 - accuracy: 0.9756
# Epoch 149/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1567 - accuracy: 0.9756
# Epoch 150/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1391 - accuracy: 0.9512
# Epoch 151/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1865 - accuracy: 0.9268
# Epoch 152/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1056 - accuracy: 0.9512
# Epoch 153/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1770 - accuracy: 0.9268
# Epoch 154/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1163 - accuracy: 0.9756
# Epoch 155/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1155 - accuracy: 0.9756
# Epoch 156/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1343 - accuracy: 0.9756
# Epoch 157/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0950 - accuracy: 0.9756
# Epoch 158/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1117 - accuracy: 0.9756
# Epoch 159/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1503 - accuracy: 0.9512
# Epoch 160/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1443 - accuracy: 0.9512
# Epoch 161/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1046 - accuracy: 0.9512
# Epoch 162/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0574 - accuracy: 0.9756
# Epoch 163/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1602 - accuracy: 0.9512
# Epoch 164/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1199 - accuracy: 0.9268
# Epoch 165/200
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0662 - accuracy: 0.9756
# Epoch 166/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1337 - accuracy: 0.9268
# Epoch 167/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1352 - accuracy: 0.9756
# Epoch 168/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1031 - accuracy: 0.9756
# Epoch 169/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1049 - accuracy: 0.9756
# Epoch 170/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1434 - accuracy: 0.9024
# Epoch 171/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0871 - accuracy: 0.9512
# Epoch 172/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1435 - accuracy: 0.9512
# Epoch 173/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1012 - accuracy: 0.9512
# Epoch 174/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1450 - accuracy: 0.9756
# Epoch 175/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0799 - accuracy: 0.9756
# Epoch 176/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1858 - accuracy: 0.9512
# Epoch 177/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0832 - accuracy: 0.9512
# Epoch 178/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2123 - accuracy: 0.9268
# Epoch 179/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1254 - accuracy: 0.9756
# Epoch 180/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1799 - accuracy: 0.9268
# Epoch 181/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1929 - accuracy: 0.9268
# Epoch 182/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1033 - accuracy: 0.9512
# Epoch 183/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0693 - accuracy: 0.9756
# Epoch 184/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1135 - accuracy: 0.9512
# Epoch 185/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1491 - accuracy: 0.9756
# Epoch 186/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1171 - accuracy: 0.9756
# Epoch 187/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1784 - accuracy: 0.9024
# Epoch 188/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1626 - accuracy: 0.9268
# Epoch 189/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1500 - accuracy: 0.9512
# Epoch 190/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0877 - accuracy: 0.9756
# Epoch 191/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1773 - accuracy: 0.9512
# Epoch 192/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0829 - accuracy: 0.9756
# Epoch 193/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0666 - accuracy: 0.9756
# Epoch 194/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2090 - accuracy: 0.8780
# Epoch 195/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2301 - accuracy: 0.8537
# Epoch 196/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1459 - accuracy: 0.9512
# Epoch 197/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1015 - accuracy: 0.9512
# Epoch 198/200
# 9/9 [==============================] - 0s 2ms/step - loss: 0.1167 - accuracy: 0.9512
# Epoch 199/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1394 - accuracy: 0.9756
# Epoch 200/200
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0856 - accuracy: 0.9756
# model created
